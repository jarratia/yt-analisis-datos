# %%
import pandas as pd
import numpy as np

# %%
#Agregar una columna a un dataframe
#Primero generamos el dataframe
data = {
  'Nombre': ['Juan', 'Ana', 'Pepe', 'Lau'],
  'Edad': [25, 33, 30, 28]
}

df = pd.DataFrame(data)
df
# Out:
#   Nombre  Edad
# 0   Juan    25
# 1    Ana    33
# 2   Pepe    30
# 3    Lau    28

# %%
#Agregar columna sin modificar en el archivo df o el diccionario
df["Ciudad"] = ["Madrid", "Barcelona", "Caracas", "Santiago de Chile"]
df
# Out:
#   Nombre  Edad             Ciudad
# 0   Juan    25             Madrid
# 1    Ana    33          Barcelona
# 2   Pepe    30            Caracas
# 3    Lau    28  Santiago de Chile

# %%
#Agregar una fila con el método .concat de pandas
new_row = pd.Series({"Nombre": "Pedro", "Edad":45, "Ciudad": "Caracas"})

#Agregamos la fila al df
df = pd.concat([df, new_row.to_frame().T], ignore_index=True)
df
# Out:
#   Nombre Edad             Ciudad
# 0   Juan   25             Madrid
# 1    Ana   33          Barcelona
# 2   Pepe   30            Caracas
# 3    Lau   28  Santiago de Chile
# 4  Pedro   45            Caracas

# %% [markdown]
# #### Entendiendo el código
# - Primero definimos el new_row con los valores a ingresar en la nueva fila.
# - Luego, utilizamos el método .concat de pandas que recibe dos argumentos, el primero es un arreglo donde el primer valor apunta al df donde agregaremos la nueva fila. El segundo elemento del arreglo es donde le decimos a new_row con el método to_frame() que aregue el elemento
# - El último argumento corresponde a ignorar el índice automático del elemento, si no se agrega esto, se repetirán índices y podría generar errores de consistencia en los datos.
#
# 🗒️.T es un tranpose o transposición, que convierte el vector en filas.

# %%
#Combinación de data frames
#Forma vertical

data2 = {
  "Nombre": ["Javier", "Carla"],
  "Edad": [32, 23],
  "Ciudad": ["La guaira", "Mendoza"]
  }

df2 = pd.DataFrame(data2)
df2
# Out:
#    Nombre  Edad     Ciudad
# 0  Javier    32  La guaira
# 1   Carla    23    Mendoza

# %%
#Combinación
df_combined = pd.concat([df, df2], ignore_index=True)
df_combined
# Out:
#    Nombre Edad             Ciudad
# 0    Juan   25             Madrid
# 1     Ana   33          Barcelona
# 2    Pepe   30            Caracas
# 3     Lau   28  Santiago de Chile
# 4   Pedro   45            Caracas
# 5  Javier   32          La guaira
# 6   Carla   23            Mendoza
